# %% [markdown]
# <a href="https://colab.research.google.com/github/chunkywizard1992/Notesforclasss/blob/main/notebooks/google_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rsxdalv/tts-generation-webui

# %%
import os
os.chdir("./tts-generation-webui")

# %%
# Run install/updates
# !git pull
# !pip install -r requirements.txt
# !python update.py

# %%
# Fix for deepspeed for tortoise
# pip uninstall deepspeed
# pip install deepspeed==0.8.3

# %%
# Fix torchvision for MusicGen
# !pip install torchvision==0.15.0+cu117 --extra-index-url https://download.pytorch.org/whl/cu117

# %%
# !python server.py --share
# Out:
# Env file not found. Creating default env.
# Config file not found. Creating default config.
# Loading extensions:
#   Loaded extension: empty_extension
#   Loaded extension: callback_save_generation_ffmpeg
#   Loaded extension: callback_save_generation_musicgen_ffmpeg
#   Loaded 2 callback_save_generation extensions.
#   Loaded 1 callback_save_generation_musicgen extensions.
# 2024-02-06 07:05:37.289879: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 07:05:37.289972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
